# %% [markdown]
# In \[5\]:
#
#     sample_set={1,34,96,73,864,"dog","hi","god"}
#     type(sample_set)
#
# Out\[5\]:
#
#     set
#
# In \[13\]:
#
#     sample_set
#
# Out\[13\]:
#
#     {1, 34, 73, 864, 96, 'dog', 'god', 'hi'}
#
# In \[14\]:
#
#     sample_set[2]
#
#     ---------------------------------------------------------------------------
#     TypeError                                 Traceback (most recent call last)
#     <ipython-input-14-e9af49f3aca4> in <module>
#     ----> 1 sample_set[2]
#
#     TypeError: 'set' object is not subscriptable
#
# In \[24\]:
#
#     sample_set.remove(34)
#     sample_set
#
#     ---------------------------------------------------------------------------
#     KeyError                                  Traceback (most recent call last)
#     <ipython-input-24-a36579ac2298> in <module>
#     ----> 1 sample_set.remove(34)
#           2 sample_set
#
#     KeyError: 34
#
# In \[19\]:
#
#     sample_set.add(99)
#     sample_set
#
# Out\[19\]:
#
#     {1, 73, 864, 96, 99, 'dog', 'god', 'hi'}
#
# In \[37\]:
#
#     sample_set.pop()
#
#     ---------------------------------------------------------------------------
#     KeyError                                  Traceback (most recent call last)
#     <ipython-input-37-c1bae6374c3b> in <module>
#     ----> 1 sample_set.pop()
#
#     KeyError: 'pop from an empty set'
#
# In \[ \]:
