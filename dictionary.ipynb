# %% [markdown]
# In \[1\]:
#
#     sample_dict={"a":"alpha",1:"first",2:"second",3:"third",1:"fourth",5:"fourth",6:"sixth"}
#     type(sample_dict)
#
# Out\[1\]:
#
#     dict
#
# In \[2\]:
#
#     sample_dict
#
# Out\[2\]:
#
#     {'a': 'alpha', 1: 'fourth', 2: 'second', 3: 'third', 5: 'fourth', 6: 'sixth'}
#
# In \[3\]:
#
#     sample_dict["a"]
#
# Out\[3\]:
#
#     'alpha'
#
# In \[4\]:
#
#     sample_dict[5]
#
# Out\[4\]:
#
#     'fourth'
#
# In \[5\]:
#
#     sample_dict["alpha"]
#
#     ---------------------------------------------------------------------------
#     KeyError                                  Traceback (most recent call last)
#     <ipython-input-5-588d477aabb1> in <module>
#     ----> 1 sample_dict["alpha"]
#
#     KeyError: 'alpha'
#
# In \[9\]:
#
#     sample_dict[5]
#
# Out\[9\]:
#
#     'fifth'
#
# In \[10\]:
#
#     sample_dict[7]
#
# Out\[10\]:
#
#     'seventh'
#
# In \[11\]:
#
#     sample_dict.reverse()
#
#     ---------------------------------------------------------------------------
#     AttributeError                            Traceback (most recent call last)
#     <ipython-input-11-30df3e04ae26> in <module>
#     ----> 1 sample_dict.reverse()
#
#     AttributeError: 'dict' object has no attribute 'reverse'
#
# In \[12\]:
#
#     sample_dict.pop("a")
#     sample_dict
#
# Out\[12\]:
#
#     {1: 'fourth', 2: 'second', 3: 'third', 5: 'fifth', 6: 'sixth', 7: 'seventh'}
#
# In \[13\]:
#
#     sample_dict.pop()
#
#     ---------------------------------------------------------------------------
#     TypeError                                 Traceback (most recent call last)
#     <ipython-input-13-c0cc9cf0c97c> in <module>
#     ----> 1 sample_dict.pop()
#
#     TypeError: pop expected at least 1 argument, got 0
