# %% [markdown]
# In \[2\]:
#
#     sample_tuple=(1,56,3.5,"hi",1+2j)
#     sample_tuple
#
# Out\[2\]:
#
#     (1, 56, 3.5, 'hi', (1+2j))
#
# In \[4\]:
#
#     sample_tuple=1,56,3.5,"hi",1+2j
#     sample_tuple
#
# Out\[4\]:
#
#     (1, 56, 3.5, 'hi', (1+2j))
#
# In \[5\]:
#
#     type(sample_tuple)
#
# Out\[5\]:
#
#     tuple
#
# In \[6\]:
#
#     sample_tuple[2]
#
# Out\[6\]:
#
#     3.5
#
# In \[7\]:
#
#     sample_tuple[7]
#
#     ---------------------------------------------------------------------------
#     IndexError                                Traceback (most recent call last)
#     <ipython-input-7-b7a95ea2e8a0> in <module>
#     ----> 1 sample_tuple[7]
#
#     IndexError: tuple index out of range
#
# In \[8\]:
#
#     sample_tuple.reverse()
#
#     ---------------------------------------------------------------------------
#     AttributeError                            Traceback (most recent call last)
#     <ipython-input-8-ad9148e49edb> in <module>
#     ----> 1 sample_tuple.reverse()
#
#     AttributeError: 'tuple' object has no attribute 'reverse'
#
# In \[9\]:
#
#     sample_tuple(3)
#
#     ---------------------------------------------------------------------------
#     TypeError                                 Traceback (most recent call last)
#     <ipython-input-9-b7ba7e1274ed> in <module>
#     ----> 1 sample_tuple(3)
#
#     TypeError: 'tuple' object is not callable
#
# In \[10\]:
#
#     sample_tuple(13)
#
#     ---------------------------------------------------------------------------
#     TypeError                                 Traceback (most recent call last)
#     <ipython-input-10-f7701c2b2f4a> in <module>
#     ----> 1 sample_tuple(13)
#
#     TypeError: 'tuple' object is not callable
#
# In \[11\]:
#
#     sample_tuple.append(5)
#
#     ---------------------------------------------------------------------------
#     AttributeError                            Traceback (most recent call last)
#     <ipython-input-11-3b12d66566fd> in <module>
#     ----> 1 sample_tuple.append(5)
#
#     AttributeError: 'tuple' object has no attribute 'append'
#
# In \[12\]:
#
#     sample_tuple.remove("hi")
#
#     ---------------------------------------------------------------------------
#     AttributeError                            Traceback (most recent call last)
#     <ipython-input-12-3662405e17c6> in <module>
#     ----> 1 sample_tuple.remove("hi")
#
#     AttributeError: 'tuple' object has no attribute 'remove'
#
# In \[13\]:
#
#     x=(1,2,3)
#     y=list(x)
#     y
#
# Out\[13\]:
#
#     [1, 2, 3]
#
# In \[14\]:
#
#     y.remove(3)
#     y
#
# Out\[14\]:
#
#     [1, 2]
#
# In \[17\]:
#
#     tuple=(10,20,30)
#     name_list=list(tuple)
#     name_list
#
# Out\[17\]:
#
#     [10, 20, 30]
#
# In \[18\]:
#
#     y.append(34)
#
# In \[ \]:
